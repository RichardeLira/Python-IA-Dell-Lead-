# %%
import pandas as pd

# %%
df = pd.read_excel(r'C:\Users\Rícharde\Documents\Dell lead\Pizza consumption Dataset.xlsx')
df.head()
# Out:
#    pizza  female  income  age    Education
# 0    109       1   15000   25   Uneducated
# 1    114       1   30000   45   Uneducated
# 2    193       1   12000   20   Uneducated
# 3    108       1   20000   28   Uneducated
# 4    220       1   15000   25  High School

# %% [markdown]
# Diferenças entre iloc e loc

# %%
df.loc[0]
# Out:
# pizza               109
# female                1
# income            15000
# age                  25
# Education    Uneducated
# Name: 0, dtype: object

# %%
df.iloc[0]
# Out:
# pizza               109
# female                1
# income            15000
# age                  25
# Education    Uneducated
# Name: 0, dtype: object

# %%
# quantidade de linhas presentes no dataset
df.index
# Out:
# RangeIndex(start=0, stop=40, step=1)

# %%
# substituiu o index pela numeração da pizza 
df.index = df['pizza']
df
# Out:
#        pizza  female  income  age        Education
# pizza
# 109      109       1   15000   25       Uneducated
# 114      114       1   30000   45       Uneducated
# 193      193       1   12000   20       Uneducated
# 108      108       1   20000   28       Uneducated
# 220      220       1   15000   25      High School
# 189      189       1   30000   35      High School
# 64        64       1   12000   40      High School
# 262      262       1   12000   22      High School
# 64        64       1   28000   30      High School
# 35        35       1   22000   21      High School
# 94        94       1   44000   40      High School
# 71        71       1   10000   21          College
# 403      403       1  222000   45          College
# 41        41       1   32000   36          College
# 10        10       1   45000   36          College
# 110      110       1   55000   40          College
# 239      239       1   29000   23          College
# ...

# %%
df.iloc[0]
# Out:
# pizza               109
# female                1
# income            15000
# age                  25
# Education    Uneducated
# Name: 109, dtype: object

# %%
df.head(10)
# Out:
#        pizza  female  income  age    Education
# pizza
# 109      109       1   15000   25   Uneducated
# 114      114       1   30000   45   Uneducated
# 193      193       1   12000   20   Uneducated
# 108      108       1   20000   28   Uneducated
# 220      220       1   15000   25  High School
# 189      189       1   30000   35  High School
# 64        64       1   12000   40  High School
# 262      262       1   12000   22  High School
# 64        64       1   28000   30  High School
# 35        35       1   22000   21  High School

# %%
# imprimir a linha 189
# loc se guia pelo indice do dataframe 
df.loc[189]
# Out:
# pizza                189
# female                 1
# income             30000
# age                   35
# Education    High School
# Name: 189, dtype: object

# %%
# se refere pelo o indice do dataframe começando do 0 como em um array convencional
df.iloc[5]
# Out:
# pizza                189
# female                 1
# income             30000
# age                   35
# Education    High School
# Name: 189, dtype: object
